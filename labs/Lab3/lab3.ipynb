# %% [markdown]
# ## Part A-3

# %%
import math
import numpy as np
import modern_robotics as mr

def ik(px,py,pz):
    # constants
    L1 = 15
    L2 = 105
    L3 = (55.95+57.75)
    L4 = 12.31

    # swtich to r1 home frame
    x_e = px * 1000
    y_e = py * 1000 + 98
    z_e = pz * 1000 - 100

    print(x_e, y_e, z_e)

    # theta3
    d = math.sqrt(x_e**2 + y_e**2 + z_e**2 - L1**2)
    # print(L3**2 + L4**2 + L2**2)
    # print(d)
    beta = math.acos((L3**2 + L4**2 + L2**2 - d**2)/(2 * L2 * math.sqrt(L3**2 + L4**2)))
    eta = math.atan(L4 / L3)
    delta = math.pi - beta
    # How do we tell the difference?
    # print(f"{math.pi}, beta: {beta}, eta: {eta}")
    theta3_elbow_down = math.pi - beta + eta
    theta3_elbow_up = math.pi + beta + eta
    theta3_elbow_up = theta3_elbow_up - 2 * math.pi if theta3_elbow_up >= 2 * math.pi - 1e-5 else theta3_elbow_up

    # theta2
    EB = math.sqrt(x_e**2 + z_e**2)
    EC = math.sqrt(L3**2+L4**2) * math.sin(delta)
    d = math.sqrt(EB**2 - EC**2)
    m = math.sqrt(x_e**2 + y_e**2 + z_e**2 - EC**2)
    phi = math.acos(abs(y_e)/m)
    alpha = math.acos(L1 / m)
    theta2 = -(alpha - phi) # direction of theta2 is opposite

    # theta1
    CK = math.sqrt(m**2 - L1**2)
    DK = L1 * math.tan(theta2)  # When theta2 is negative, DK will be negative, too
    DC = CK + DK
    # print(f"CK={CK},DK={DK},DC={DC}")
    BO = DC*math.cos(theta2)
    AO = math.sqrt(x_e**2 + z_e**2)
    # print(f"AO={AO},BO={BO}")
    epsilon = math.acos(BO/AO)
    gamma = math.atan(-z_e/x_e)
    # print(f"epsilon: {epsilon*180/np.pi}, gamma: {gamma*180/np.pi}")
    theta1_elbow_up = -epsilon + gamma
    theta1_elbow_down = epsilon + gamma # direction of theta1 is opposite

    return [theta1_elbow_down, theta2, theta3_elbow_down]

# %%
x =  0.13347017765
y = -0.215384870768
z = 0.131943851709

x, y, z = 0.21935526076282338,-0.11304791928157147,0.10173518152924917
thetas = ik(x,y,z)
print(thetas)
print(f"({x},{y},{z},{[xt*180/np.pi for xt in thetas]})")
# Out:
# 219.35526076282338 -15.047919281571467 1.7351815292491608
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\KandaMaya\Documents\University\4A\ECE486\labs\Lab3\lab3.ipynb Cell 3' in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/KandaMaya/Documents/University/4A/ECE486/labs/Lab3/lab3.ipynb#ch0000002?line=2'>3</a> z = 0.131943851709
#       <a href='vscode-notebook-cell:/c%3A/Users/KandaMaya/Documents/University/4A/ECE486/labs/Lab3/lab3.ipynb#ch0000002?line=4'>5</a> x, y, z = 0.21935526076282338,-0.11304791928157147,0.10173518152924917
# ----> <a href='vscode-notebook-cell:/c%3A/Users/KandaMaya/Documents/University/4A/ECE486/labs/Lab3/lab3.ipynb#ch0000002?line=5'>6</a> thetas = ik(x,y,z)
       0.22550551, 0.22607235, 0.2266256 , 0.22716505, 0.22769048,
       0.22820171, 0.22869852, 0.22918071, 0.22964807, 0.23010041,
       0.23053751, 0.23095917, 0.23136519, 0.23175536, 0.23212948,
       0.23248734, 0.23282875, 0.23315348, 0.23346135, 0.23375214,
       0.23402566, 0.23428169, 0.23452003, 0.23474048, 0.23494283,
       0.23512689, 0.23529243, 0.23543927, 0.23556719, 0.23567599,
       0.23576547, 0.23583542, 0.23588564, 0.23591592, 0.23592606]
def PoE_3D(theta1, theta2, theta3):
    M = np.array([
        [1, 0, 0, (105 + 55.95 + 57.75)/1000],
        [0, 1, 0, (-98 + (-15))/1000],
        [0, 0, 1, (100 - 12.31)/1000],
        [0, 0, 0, 1]
    ])
    omega_1 = np.array([0,1,0])
    omega_2 = np.array([0,0,1])
    omega_3 = np.array([0,-1,0])

    q_1 = np.array([0,-98,100])/1000
    q_2 = np.array([0,-98,100])/1000
    q_3 = np.array([105,-113,100])/1000

    v_1 = - np.cross(omega_1,q_1)
    v_2 = - np.cross(omega_2,q_2) 
    v_3 = - np.cross(omega_3,q_3) 
    
    S1 = mr.MatrixExp6(mr.VecTose3(np.concatenate((omega_1,v_1),axis=0))*theta1)
    S2 = mr.MatrixExp6(mr.VecTose3(np.concatenate((omega_2,v_2),axis=0))*theta2)
    S3 = mr.MatrixExp6(mr.VecTose3(np.concatenate((omega_3,v_3),axis=0))*theta3)

    T_05 = S1.dot(S2).dot(S3).dot(M)
    return T_05

# %%
for index, coords in enumerate(zip(X1, Y1, Z1)):
    (x, y, z) = coords
    thetas = ik(x, y, z)

    if thetas[0] <= 7 or thetas[0] > upper_limit:
        print("OUT OF LIMIT")
    T = PoE_3D(thetas[0], thetas[1], thetas[2])
    x_e, y_e, z_e = T[0][3], T[1][3], T[2][3]
    if not np.isclose(x, x_e):
        print(f"idx: {index} real x: {x}, generated x: {x_e}")
    if not np.isclose(y, y_e):
        print(f"idx: {index} real y: {y}, generated y: {y_e}")
    if not np.isclose(z, z_e):
        print(f"idx: {index} real z: {z}, generated z: {z_e}")

# %%
for idx, z in enumerate(Z1[1:]):
    if Z1[idx-1] >= z:
        print(f"{idx} FUCK")

for idx, y in enumerate(Y1[1:]):
    if Y1[idx-1] <= y:
        print(f"{idx} FUCK")

for idx, x in enumerate(X1[1:]):
    if X1[idx-1] <= x:
        print(f"{idx} FUCK")
# Out:
# 0 FUCK
# 0 FUCK
# 0 FUCK

# %% [markdown]
# ## Part A-4

# %%
import modern_robotics as mr

# Straight line trajectory

# Initial configuraiton
Xstart = np.array([
        [1, 0, 0, (105 + 55.95 + 57.75)/1000],
        [0, 1, 0, (-98 + (-15))/1000],
        [0, 0, 1, (100 - 12.31)/1000],
        [0, 0, 0, 1]
    ])

# (-30,-20, 30)
Xend = np.array([
        [0.45476947, 0.29619813, -0.83991154, 0.14305238],
        [-0.29619813, 0.93969262, 0.17101007, -0.18379037],
        [0.83991154, 0.17101007, 0.51507684, 0.23592606],
        [0, 0, 0, 1]
    ])

# (30,-45,30)

Xend2 = np.array([
       [0.78033009,	0.61237244,	0.12682648,	0.14227582],
        [-0.61237244,	0.70710678,	0.35355339,	-0.2568318],
        [0.12682648,	-0.35355339,	0.9267767,	0.07119174],
        [0,	0,	0,	1]
    ])

Tf = 5
N = 200
method = 3

straight_trajectory = mr.CartesianTrajectory(Xstart, Xend, Tf, N, method)

# Screw trajectory

# Initial configuraiton
Xstart = np.array([
        [1, 0, 0, (105 + 55.95 + 57.75)/1000],
        [0, 1, 0, (-98 + (-15))/1000],
        [0, 0, 1, (100 - 12.31)/1000],
        [0, 0, 0, 1]
    ])

#(-30,-20, 30)
Xend = np.array([
        [ 0.45476947,  0.29619813, -0.83991154,  0.14305238],
       [-0.29619813,  0.93969262,  0.17101007, -0.18379037],
       [ 0.83991154,  0.17101007,  0.51507684,  0.23592606],
       [ 0.        ,  0.        ,  0.        ,  1.        ]
    ])


Tf = 5
N = 200
method = 3

screw_trajectory = mr.ScrewTrajectory(Xstart, Xend, Tf, N, method)

# %%
from mpl_toolkits import mplot3d
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
X1 = np.zeros(len(straight_trajectory))
Y1 = np.zeros(len(straight_trajectory))
Z1 = np.zeros(len(straight_trajectory))

for i in range(len(straight_trajectory)):
    X1[i] = straight_trajectory[i][:,3][0]
    Y1[i] = straight_trajectory[i][:,3][1]
    Z1[i] = straight_trajectory[i][:,3][2]

X2 = np.zeros(len(screw_trajectory))
Y2 = np.zeros(len(screw_trajectory))
Z2 = np.zeros(len(screw_trajectory))

for i in range(len(screw_trajectory)):
    X2[i] = screw_trajectory[i][:,3][0]
    Y2[i] = screw_trajectory[i][:,3][1]
    Z2[i] = screw_trajectory[i][:,3][2]

# %%
np.shape([X2,Y2,Z2])

# %%
a_file = open("Lab3_Trajectory.txt", "w")
np.savetxt(a_file, [X2,Y2,Z2])
a_file.close()

# %%
loaded_trajectory = np.loadtxt("Lab3_Trajectory.txt")

# %%
ax = plt.axes(projection='3d')

# Data for a three-dimensional line
zline = np.linspace(0, 0.3, 100)
xline = np.linspace(0, 0.3, 100)
yline = np.linspace(0, 0.3, 100)
ax.plot3D(xline, yline, zline, 'gray')

# Data for three-dimensional scattered points
ax.scatter3D(X1, Y1, Z1, cmap='Greens');

# %%
ax = plt.axes(projection='3d')

# Data for a three-dimensional line
zline = np.linspace(0, 0.3, 100)
xline = np.linspace(0, 0.3, 100)
yline = np.linspace(0, 0.3, 100)
ax.plot3D(xline, yline, zline, 'gray')

# Data for three-dimensional scattered points
ax.scatter3D(X2, Y2, Z2, cmap='Greens');

# %% [markdown]
# ## Part A-5

# %%
x = loaded_trajectory[0][10]
y = loaded_trajectory[1][10]
z = loaded_trajectory[2][10]
print(x,y,z)

# %%
trj_joints = []
for i in range(200):
    x = loaded_trajectory[0][i]
    y = loaded_trajectory[1][i]
    z = loaded_trajectory[2][i]
    thetas = ik(x,y,z)
    print(f"(i={i}:{x},{y},{z},{[xt*180/np.pi for xt in thetas]}")
    trj_joints.append(thetas)

# %%
trj_joints
